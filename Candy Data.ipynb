# %%
import pandas as pd
filepath = 'candyhierarchy2017.csv'
df = pd.read_csv(filepath)

# %%
df.shape
df.head(10)
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2460 entries, 0 to 2459
# Columns: 120 entries, Internal ID to Click Coordinates (x, y)
# dtypes: float64(4), int64(1), object(115)
# memory usage: 2.3+ MB
# Internal ID                    0
# Q1: GOING OUT?               110
# Q2: GENDER                    41
# Q3: AGE                       84
# Q4: COUNTRY                   64
#                             ...
# Q12: MEDIA [Daily Dish]     2375
# Q12: MEDIA [Science]        1098
# Q12: MEDIA [ESPN]           2361
# Q12: MEDIA [Yahoo]          2393
# Click Coordinates (x, y)     855
# Length: 120, dtype: int64

# %% [markdown]
# the data contains alot of missing values, candy rating columns are stored correctly "JOY", "MEH","DESPAIR"

# %%
#df = df.drop(columns=['internal id'])

# %%
def simplify_name(name):
    name = name.lower().strip()
    if 'q6 |' in name:
        name = name.split('|')[-1].strip()
    elif ':' in name:
        name = name.split(':')[-1].strip()
    while '__' in name:
        name = name.replace('__', '_')
    return name.strip('_')

df.columns = [simplify_name(col) for col in df.columns]

# %%
min_non_null = int(len(df) * 0.20)
df = df.dropna(axis=1, thresh=min_non_null)

# %%
df.shape
# Out:
# (2460, 115)

# %%
min_non_null = int(len(df.columns) * 0.20)
df = df.dropna(axis=0, thresh=min_non_null)

# %%
df.shape
# Out:
# (1796, 115)

# %%
df.columns
# Out:
# Index(['internal id', 'going out?', 'gender', 'age', 'country',
#        'state, province, county, etc', '100 grand bar',
#        'anonymous brown globs that come in black and orange wrappers\t(a.k.a. mary janes)',
#        'any full-sized candy bar', 'black jacks',
#        ...
#        'whatchamacallit bars', 'white bread', 'whole wheat anything',
#        'york peppermint patties', 'joy other', 'despair other', 'dress', 'day',
#        'media [science]', 'click coordinates (x, y)'],
#       dtype='object', length=115)

# %%
df['going out?'] = df['going out?'].fillna('No')

# %%
df['gender'].value_counts()
# Out:
# gender
# Male                  1082
# Female                 618
# I'd rather not say      60
# Other                   26
# Name: count, dtype: int64

# %%
unspecified_list = ['I\'d rather not say', 'Other']
df['gender'] = df['gender'].replace(unspecified_list, 'Unspecified').fillna('Unspecified')

# %%
df['age'] = pd.to_numeric(df['age'], errors='coerce')
age_median = df['age'].median()
df['age'] = df['age'].fillna(age_median).astype(int)

# %%
df['country'].value_counts()
# Out:
# country
# USA                               534
# United States                     388
# usa                               160
# Canada                            123
# US                                101
#                                  ...
# United Statea                       1
# subscribe to dm4uz3 on youtube      1
# USA USA USA!!!!                     1
# I don't know anymore                1
# Fear and Loathing                   1
# Name: count, Length: 100, dtype: int64

# %%
def simplify_country(country):
    if pd.isna(country):
        return None
    country = str(country).lower().strip()
    if 'united kingdom' in country or 'uk' in country or 'scotland' in country or 'england' in country:
        return 'United Kingdom'
    if 'united states' in country or 'usa' in country or 'us' in country or 'america' in country or 'u.s.' in country or'u.s.a.' in country:
        return 'United States'
    if 'canada' in country:
        return 'Canada'
    return country.title()

# %%
df['country'] = df['country'].apply(simplify_country).fillna('Unknown')

# %%
df['country'].value_counts()
# Out:
# country
# United States                     1524
# Canada                             158
# United Kingdom                      22
# Unknown                             21
# Germany                              7
# Netherlands                          4
# France                               3
# Ireland                              3
# Japan                                3
# United State                         2
# Switzerland                          2
# Denmark                              2
# Mexico                               2
# Unites States                        2
# Murica                               1
# U S                                  1
# Costa Rica                           1
# Insanity Lately                      1
# United Staes                         1
# Uae                                  1
# North Carolina                       1
# Earth                                1
# Europe                               1
# A                                    1
# Pittsburgh                           1
# 'Merica                              1
# Greece                               1
# Cascadia                             1
# Trumpistan                           1
# New York                             1
# Can                                  1
# California                           1
# Korea                                1
# United Sates                         1
# Iceland                              1
# Ahem....Amerca                       1
# South Korea                          1
# New Jersey                           1
# Canae                                1
# United Stated                        1
# United Statss                        1
# Endland                              1
# Atlantis                             1
# Murrika                              1
# Alaska                               1
# Singapore                            1
# Taiwan                               1
# China                                1
# Spain                                1
# Narnia                               1
# U S A                                1
# United Statea                        1
# Subscribe To Dm4Uz3 On Youtube       1
# I Don'T Know Anymore                 1
# Fear And Loathing                    1
# Name: count, dtype: int64

# %%
keyword = 'state'
found_columns = [col for col in df.columns if keyword.lower() in col.lower()]
print(found_columns)
# Out:
# ['state, province, county, etc']

# %%
df['state, province, county, etc'].value_counts()
# Out:
# state, province, county, etc
# California                                        108
# CA                                                 64
# Texas                                              44
# Illinois                                           42
# Oregon                                             39
#                                                  ...
# Connecticut                                         1
# ill                                                 1
# Psychotic                                           1
# New York County, New York City, New York State      1
# West Yorkshire                                      1
# Name: count, Length: 431, dtype: int64

# %%
df['state, province, county, etc'] = df['state, province, county, etc'].str.lower().str.strip().fillna('Unknown')

# %%
df['state, province, county, etc'].value_counts()
# Out:
# state, province, county, etc
# california                                            137
# ca                                                     85
# ontario                                                57
# illinois                                               55
# texas                                                  51
#                                                      ...
# chicago, il                                             1
# st. augustine florida                                   1
# the democratic people's republic of north carolina      1
# pennsylvania, northampton couny, easton                 1
# psychotic                                               1
# Name: count, Length: 276, dtype: int64

# %%
df.columns[6:]
# Out:
# Index(['100 grand bar',
#        'anonymous brown globs that come in black and orange wrappers\t(a.k.a. mary janes)',
#        'any full-sized candy bar', 'black jacks', 'bonkers (the candy)',
#        'bonkers (the board game)', 'bottle caps', 'box'o'raisins',
#        'broken glow stick', 'butterfinger',
#        ...
#        'whatchamacallit bars', 'white bread', 'whole wheat anything',
#        'york peppermint patties', 'joy other', 'despair other', 'dress', 'day',
#        'media [science]', 'click coordinates (x, y)'],
#       dtype='object', length=109)

# %%
def detect_candy_col(s):
    values = s.dropna().astype(str).str.strip().str.upper()
    check = values.isin(['JOY', 'MEH', 'DESPAIR'])
    return check.sum() >= max(5, int(0.3 * len(values)))

candy_cols = [i for i in df.columns if detect_candy_col(df[i])]

# %%
candy_cols
# Out:
# ['100 grand bar',
#  'anonymous brown globs that come in black and orange wrappers\t(a.k.a. mary janes)',
#  'any full-sized candy bar',
#  'black jacks',
#  'bonkers (the candy)',
#  'bonkers (the board game)',
#  'bottle caps',
#  "box'o'raisins",
#  'broken glow stick',
#  'butterfinger',
#  'cadbury creme eggs',
#  'candy corn',
#  'candy that is clearly just the stuff given out for free at restaurants',
#  'caramellos',
#  'cash, or other forms of legal tender',
#  'chardonnay',
#  'chick-o-sticks (we don’t know what that is)',
#  'chiclets',
#  'coffee crisp',
#  'creepy religious comics/chick tracts',
#  'dental paraphenalia',
#  'dots',
#  'dove bars',
#  'fuzzy peaches',
#  'generic brand acetaminophen',
#  'glow sticks',
#  'goo goo clusters',
#  "good n' plenty",
#  'gum from baseball cards',
#  'gummy bears straight up',
#  'hard candy',
#  'healthy fruit',
#  'heath bar',
#  "hershey's dark chocolate",
#  'hershey’s milk chocolate',
#  "hershey's kisses",
#  'hugs (actual physical hugs)',
#  'jolly rancher (bad flavor)',
#  'jolly ranchers (good flavor)',
#  'joyjoy (mit iodine!)',
#  'junior mints',
#  'senior mints',
#  'kale smoothie',
#  'kinder happy hippo',
#  'kit kat',
#  'laffytaffy',
#  'lemonheads',
#  'licorice (not black)',
#  'licorice (yes black)',
#  'lindt truffle',
#  'lollipops',
#  'mars',
#  'maynards',
#  'mike and ike',
#  'milk duds',
#  'milky way',
#  'regular m&ms',
#  'peanut m&m’s',
#  "blue m&m's",
#  "red m&m's",
#  "green party m&m's",
#  "independent m&m's",
#  "abstained from m&m'ing.",
#  'minibags of chips',
#  'mint kisses',
#  'mint juleps',
#  'mr. goodbar',
#  'necco wafers',
#  'nerds',
#  'nestle crunch',
#  "now'n'laters",
#  'peeps',
#  'pencils',
#  'pixy stix',
#  'real housewives of orange county season 9 blue-ray',
#  'reese’s peanut butter cups',
#  "reese's pieces",
#  'reggie jackson bar',
#  'rolos',
#  'sandwich-sized bags filled with booberry crunch',
#  'skittles',
#  'smarties (american)',
#  'smarties (commonwealth)',
#  'snickers',
#  'sourpatch kids (i.e. abominations of nature)',
#  'spotted dick',
#  'starburst',
#  'sweet tarts',
#  'swedish fish',
#  'sweetums (a friend to diabetes)',
#  'take 5',
#  'tic tacs',
#  'those odd marshmallow circus peanut things',
#  'three musketeers',
#  'tolberone something or other',
#  'trail mix',
#  'twix',
#  'vials of pure high fructose corn syrup, for main-lining into your vein',
#  'vicodin',
#  'whatchamacallit bars',
#  'white bread',
#  'whole wheat anything',
#  'york peppermint patties']

# %%
def candy_col_cleaning (x):
    if pd.isna(x):
        return pd.NA
    y = str(x).strip().upper()
    if y in ["JOY", "MEH", "DESPAIR"]:
        return y
    return pd.NA

# %%
for i in candy_cols:
    df[i] = df[i].apply(candy_col_cleaning)

# %%
df.shape
# Out:
# (1796, 115)

# %%
df['dress'].value_counts(dropna=False)
# Out:
# dress
# White and gold    1077
# Blue and black     634
# NaN                 85
# Name: count, dtype: int64

# %%
df['dress'] = df['dress'].fillna("Unknown")

# %%
df['dress'].value_counts(dropna=False)
# Out:
# dress
# White and gold    1077
# Blue and black     634
# Unknown             85
# Name: count, dtype: int64

# %%
df['day'].value_counts(dropna=False)
# Out:
# day
# Friday    1090
# Sunday     641
# NaN         65
# Name: count, dtype: int64

# %%
df['day'] = df['day'].fillna("Unknown")

# %%
df['day'].value_counts(dropna=False)
# Out:
# day
# Friday     1090
# Sunday      641
# Unknown      65
# Name: count, dtype: int64

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# despair other                   1080
# joy other                        886
# media [science]                  438
# joyjoy (mit iodine!)             362
# maynards                         360
#                                 ...
# going out?                         0
# state, province, county, etc       0
# age                                0
# day                                0
# dress                              0
# Length: 115, dtype: int64

# %%
df = df.drop(columns=['despair other'])

# %%
df = df.drop(columns=['joy other'])

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# media [science]                 438
# joyjoy (mit iodine!)            362
# maynards                        360
# reggie jackson bar              350
# bonkers (the board game)        343
#                                ...
# state, province, county, etc      0
# age                               0
# country                           0
# day                               0
# dress                             0
# Length: 113, dtype: int64

# %%
df.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('O'), dtype('float64')], dtype=object)

# %%
for i in candy_cols:
    print(i, df[i].unique())
# Out:
# 100 grand bar ['MEH' 'JOY' <NA> 'DESPAIR']
# anonymous brown globs that come in black and orange wrappers	(a.k.a. mary janes) ['DESPAIR' 'MEH' 'JOY' <NA>]
# any full-sized candy bar ['JOY' 'MEH' <NA> 'DESPAIR']
# black jacks ['MEH' 'DESPAIR' <NA> 'JOY']
# bonkers (the candy) ['DESPAIR' 'MEH' <NA> 'JOY']
# bonkers (the board game) ['DESPAIR' <NA> 'MEH' 'JOY']
# bottle caps ['DESPAIR' 'MEH' 'JOY' <NA>]
# box'o'raisins ['DESPAIR' 'MEH' 'JOY' <NA>]
# broken glow stick ['DESPAIR' 'JOY' 'MEH' <NA>]
# butterfinger ['DESPAIR' 'MEH' 'JOY' <NA>]
# cadbury creme eggs ['MEH' 'DESPAIR' 'JOY' <NA>]
# candy corn ['MEH' 'DESPAIR' 'JOY' <NA>]
# candy that is clearly just the stuff given out for free at restaurants ['DESPAIR' 'MEH' 'JOY' <NA>]
# caramellos ['MEH' 'JOY' <NA> 'DESPAIR']
# cash, or other forms of legal tender ['JOY' 'MEH' 'DESPAIR' <NA>]
# chardonnay ['MEH' 'JOY' <NA> 'DESPAIR']
# chick-o-sticks (we don’t know what that is) ['DESPAIR' 'JOY' 'MEH' <NA>]
# chiclets ['DESPAIR' 'MEH' <NA> 'JOY']
# coffee crisp ['DESPAIR' 'MEH' 'JOY' <NA>]
# creepy religious comics/chick tracts ['DESPAIR' 'JOY' 'MEH' <NA>]
# dental paraphenalia ['DESPAIR' 'MEH' 'JOY' <NA>]
# dots ['MEH' 'JOY' 'DESPAIR' <NA>]
# dove bars ['JOY' 'MEH' 'DESPAIR' <NA>]
# fuzzy peaches ['DESPAIR' 'MEH' <NA> 'JOY']
# generic brand acetaminophen ['DESPAIR' 'MEH' <NA> 'JOY']
# glow sticks ['DESPAIR' 'JOY' 'MEH' <NA>]
# goo goo clusters ['DESPAIR' 'JOY' 'MEH' <NA>]
# good n' plenty ['MEH' 'DESPAIR' 'JOY' <NA>]
# gum from baseball cards ['DESPAIR' 'MEH' 'JOY' <NA>]
# gummy bears straight up ['MEH' 'JOY' 'DESPAIR' <NA>]
# hard candy ['MEH' 'DESPAIR' 'JOY' <NA>]
# healthy fruit ['DESPAIR' 'MEH' 'JOY' <NA>]
# heath bar ['MEH' 'DESPAIR' 'JOY' <NA>]
# hershey's dark chocolate ['JOY' 'MEH' 'DESPAIR' <NA>]
# hershey’s milk chocolate ['JOY' 'MEH' 'DESPAIR' <NA>]
# hershey's kisses ['MEH' 'JOY' 'DESPAIR' <NA>]
# hugs (actual physical hugs) ['DESPAIR' 'MEH' 'JOY' <NA>]
# jolly rancher (bad flavor) ['DESPAIR' 'MEH' 'JOY' <NA>]
# jolly ranchers (good flavor) ['MEH' 'JOY' 'DESPAIR' <NA>]
# joyjoy (mit iodine!) ['DESPAIR' 'MEH' <NA> 'JOY']
# junior mints ['DESPAIR' 'JOY' 'MEH' <NA>]
# senior mints ['DESPAIR' <NA> 'MEH' 'JOY']
# kale smoothie ['DESPAIR' 'JOY' 'MEH' <NA>]
# kinder happy hippo ['DESPAIR' 'MEH' 'JOY' <NA>]
# kit kat ['JOY' 'MEH' 'DESPAIR' <NA>]
# laffytaffy ['DESPAIR' 'JOY' 'MEH' <NA>]
# lemonheads ['MEH' 'JOY' 'DESPAIR' <NA>]
# licorice (not black) ['MEH' 'JOY' 'DESPAIR' <NA>]
# licorice (yes black) ['JOY' 'DESPAIR' 'MEH' <NA>]
# lindt truffle ['MEH' 'JOY' 'DESPAIR' <NA>]
# lollipops ['DESPAIR' 'MEH' 'JOY' <NA>]
# mars ['DESPAIR' 'JOY' 'MEH' <NA>]
# maynards ['DESPAIR' 'MEH' <NA> 'JOY']
# mike and ike ['MEH' 'JOY' 'DESPAIR' <NA>]
# milk duds ['MEH' 'DESPAIR' 'JOY' <NA>]
# milky way ['JOY' 'MEH' 'DESPAIR' <NA>]
# regular m&ms ['JOY' 'MEH' 'DESPAIR' <NA>]
# peanut m&m’s ['MEH' 'JOY' <NA> 'DESPAIR']
# blue m&m's ['JOY' 'MEH' 'DESPAIR' <NA>]
# red m&m's ['JOY' 'MEH' 'DESPAIR' <NA>]
# green party m&m's ['JOY' 'MEH' <NA> 'DESPAIR']
# independent m&m's ['JOY' 'MEH' <NA> 'DESPAIR']
# abstained from m&m'ing. ['DESPAIR' 'MEH' <NA> 'JOY']
# minibags of chips ['DESPAIR' 'JOY' 'MEH' <NA>]
# mint kisses ['MEH' 'DESPAIR' 'JOY' <NA>]
# mint juleps ['DESPAIR' 'MEH' 'JOY' <NA>]
# mr. goodbar ['DESPAIR' 'MEH' 'JOY' <NA>]
# necco wafers ['DESPAIR' 'MEH' 'JOY' <NA>]
# nerds ['DESPAIR' 'MEH' 'JOY' <NA>]
# nestle crunch ['JOY' 'MEH' <NA> 'DESPAIR']
# now'n'laters ['DESPAIR' 'MEH' 'JOY' <NA>]
# peeps ['DESPAIR' 'MEH' <NA> 'JOY']
# pencils ['DESPAIR' 'MEH' 'JOY' <NA>]
# pixy stix ['DESPAIR' 'JOY' 'MEH' <NA>]
# real housewives of orange county season 9 blue-ray ['DESPAIR' 'MEH' <NA> 'JOY']
# reese’s peanut butter cups ['JOY' 'MEH' 'DESPAIR' <NA>]
# reese's pieces ['JOY' 'MEH' 'DESPAIR' <NA>]
# reggie jackson bar ['DESPAIR' 'MEH' <NA> 'JOY']
# rolos ['JOY' 'MEH' 'DESPAIR' <NA>]
# sandwich-sized bags filled with booberry crunch ['DESPAIR' <NA> 'MEH' 'JOY']
# skittles ['DESPAIR' 'JOY' 'MEH' <NA>]
# smarties (american) ['DESPAIR' 'JOY' 'MEH' <NA>]
# smarties (commonwealth) ['DESPAIR' 'MEH' 'JOY' <NA>]
# snickers ['MEH' 'JOY' <NA> 'DESPAIR']
# sourpatch kids (i.e. abominations of nature) ['DESPAIR' 'MEH' 'JOY' <NA>]
# spotted dick ['DESPAIR' 'MEH' <NA> 'JOY']
# starburst ['MEH' 'JOY' 'DESPAIR' <NA>]
# sweet tarts ['DESPAIR' 'MEH' 'JOY' <NA>]
# swedish fish ['MEH' 'JOY' 'DESPAIR' <NA>]
# sweetums (a friend to diabetes) ['DESPAIR' 'MEH' <NA> 'JOY']
# take 5 ['DESPAIR' 'JOY' 'MEH' <NA>]
# tic tacs ['DESPAIR' 'MEH' 'JOY' <NA>]
# those odd marshmallow circus peanut things ['DESPAIR' 'MEH' <NA> 'JOY']
# three musketeers ['JOY' 'DESPAIR' 'MEH' <NA>]
# tolberone something or other ['JOY' 'MEH' <NA> 'DESPAIR']
# trail mix ['DESPAIR' 'MEH' 'JOY' <NA>]
# twix ['JOY' 'MEH' 'DESPAIR' <NA>]
# vials of pure high fructose corn syrup, for main-lining into your vein ['DESPAIR' 'MEH' 'JOY' <NA>]
# vicodin ['DESPAIR' 'JOY' 'MEH' <NA>]
# whatchamacallit bars ['DESPAIR' 'JOY' 'MEH' <NA>]
# white bread ['DESPAIR' 'JOY' <NA> 'MEH']
# whole wheat anything ['DESPAIR' 'MEH' <NA> 'JOY']
# york peppermint patties ['DESPAIR' 'JOY' 'MEH' <NA>]

# %%
for col in ['gender', 'dress', 'day', 'country']:
    print(col, df[col].unique())
# Out:
# gender ['Male' 'Female' 'Unspecified']
# dress ['White and gold' 'Unknown' 'Blue and black']
# day ['Sunday' 'Friday' 'Unknown']
# country ['United States' 'Unknown' 'Canada' 'Murica' 'United Kingdom'
#  'United Staes' 'Uae' 'France' 'Mexico' 'Unites States' 'North Carolina'
#  'Netherlands' 'Europe' 'Earth' 'U S' 'Costa Rica' 'Cascadia'
#  'Insanity Lately' 'Greece' "'Merica" 'Pittsburgh' 'United State' 'A'
#  'Can' 'Canae' 'New York' 'Trumpistan' 'Ireland' 'United Sates' 'Korea'
#  'California' 'Japan' 'Iceland' 'Denmark' 'Switzerland' 'Ahem....Amerca'
#  'South Korea' 'New Jersey' 'United Stated' 'Germany' 'United Statss'
#  'Endland' 'Atlantis' 'Murrika' 'Alaska' 'Singapore' 'Taiwan' 'China'
#  'Spain' 'Narnia' 'U S A' 'United Statea' 'Subscribe To Dm4Uz3 On Youtube'
#  "I Don'T Know Anymore" 'Fear And Loathing']

# %%
df.head(10)
# Out:
#     internal id going out?  gender  age        country  \
# 1      90272821         No    Male   44  United States
# 3      90272840         No    Male   40  United States
# 4      90272841         No    Male   23  United States
# 5      90272852         No    Male   42        Unknown
# 7      90272854         No    Male   33         Canada
# 8      90272858         No    Male   40         Canada
# 9      90272859         No  Female   53  United States
# 11     90272865         No    Male   56         Canada
# 12     90272866         No    Male   64  United States
# 13     90272867        Yes    Male   43         Murica
#
#    state, province, county, etc 100 grand bar  \
# 1                            nm           MEH
# 3                            or           MEH
# 4                      exton pa           JOY
# 5                       Unknown           JOY
# 7                       ontario           JOY
# 8                       ontario           JOY
# 9                            wa           MEH
# 11                       quebec           JOY
# 12                           ny           MEH
# 13                   california           JOY
#
#    anonymous brown globs that come in black and orange wrappers\t(a.k.a. mary janes)  \
# 1                                             DESPAIR
# 3                                             DESPAIR
# 4                                             DESPAIR
# 5                                             DESPAIR
# 7                                             DESPAIR
# 8                                             DESPAIR
# 9                                             DESPAIR
# 11                                                MEH
# 12                                                MEH
# 13                                            DESPAIR
#
#    any full-sized candy bar black jacks  ...  \
# 1                       JOY         MEH  ...
# 3                       JOY         MEH  ...
# 4                       JOY     DESPAIR  ...
# 5                       JOY        <NA>  ...
# 7                       JOY     DESPAIR  ...
# 8                       JOY         MEH  ...
# 9                       JOY         MEH  ...
# 11                      JOY         MEH  ...
# 12                      JOY         MEH  ...
# 13                      JOY         MEH  ...
#
#    vials of pure high fructose corn syrup, for main-lining into your vein  \
# 1                                             DESPAIR
# 3                                             DESPAIR
# 4                                                 MEH
# 5                                             DESPAIR
# 7                                                 JOY
# 8                                                 MEH
# 9                                             DESPAIR
# 11                                            DESPAIR
# 12                                                JOY
# 13                                            DESPAIR
#
#     vicodin whatchamacallit bars white bread whole wheat anything  \
# 1   DESPAIR              DESPAIR     DESPAIR              DESPAIR
# 3       JOY                  JOY     DESPAIR              DESPAIR
# 4       JOY                  JOY     DESPAIR              DESPAIR
# 5   DESPAIR                  JOY     DESPAIR              DESPAIR
# 7       MEH              DESPAIR     DESPAIR              DESPAIR
# 8   DESPAIR                  MEH     DESPAIR              DESPAIR
# 9   DESPAIR                  MEH     DESPAIR              DESPAIR
# 11      MEH                  MEH         JOY              DESPAIR
# 12      JOY              DESPAIR     DESPAIR              DESPAIR
# 13  DESPAIR                  JOY     DESPAIR              DESPAIR
#
#    york peppermint patties           dress      day media [science]  \
# 1                  DESPAIR  White and gold   Sunday             1.0
# 3                  DESPAIR  White and gold   Sunday             1.0
# 4                      JOY  White and gold   Friday             1.0
# 5                      JOY         Unknown  Unknown             1.0
# 7                  DESPAIR  Blue and black   Friday             1.0
# 8                  DESPAIR  Blue and black   Sunday             1.0
# 9                      MEH  White and gold   Sunday             1.0
# 11                     MEH  White and gold   Friday             1.0
# 12                     MEH  White and gold   Sunday             1.0
# 13                     JOY  White and gold   Sunday             1.0
#
#    click coordinates (x, y)
# 1                  (84, 25)
# 3                  (75, 23)
# 4                  (70, 10)
# 5                  (75, 23)
# 7                   (55, 5)
# 8                  (76, 24)
# 9                  (70, 28)
# 11                 (73, 24)
# 12                 (77, 24)
# 13                      NaN
#
# [10 rows x 113 columns]

# %% [markdown]
#  -i dropped internal id column because it serves no purpose
#  -dropped rows,columns with alot of missing values
#  -renamed columns for easy access
#  -cleaned gender column and changed 'i'd rather not say','other' to unspecified
#  -converted age column to numeric
#  -for country column i grouped misspelling and filled all missing values with unknown
#  -identified candy columns and filled missing values with nan
#  -dropped joyother, despairother columns
#  -for dress,day columns filled missing values with unknown

# %%
candy = [col for col in df.columns if detect_candy_col(df[col])]
rating = {'JOY': 1,'MEH': 0,'DESPAIR': -1,'No Opinion': 0}
mean_scores = df[candy].replace(rating).mean().sort_values(ascending=False)

# %%
most_loved = mean_scores.head(10).to_frame(name='Average_Score')
most_hated = mean_scores.tail(10).to_frame(name='Average_Score').sort_values(by='Average_Score', ascending=True)

# %%
print(most_hated)
print(most_loved)
# Out:
#                                                    Average_Score
# broken glow stick                                      -0.912721
# white bread                                            -0.828538
# real housewives of orange county season 9 blue-ray     -0.813708
# gum from baseball cards                                -0.813073
# kale smoothie                                           -0.77331
# dental paraphenalia                                     -0.75905
# candy that is clearly just the stuff given out ...     -0.726964
# whole wheat anything                                    -0.68418
# creepy religious comics/chick tracts                   -0.660592
# spotted dick                                           -0.641318
#                                      Average_Score
# any full-sized candy bar                  0.862668
# reese’s peanut butter cups                0.787521
# kit kat                                    0.78083
# cash, or other forms of legal tender       0.77191
# twix                                      0.757919
# snickers                                  0.745475
# tolberone something or other              0.704675
# lindt truffle                             0.676808
# peanut m&m’s                              0.653415
# nestle crunch                             0.615909
